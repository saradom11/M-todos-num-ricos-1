# %% [markdown]
# # Gráfica de $f(x)=x - 3^{-x}$

# %%
import matplotlib.pyplot as plt #Para graficar
import numpy as np #Para hacer caclculos con arreglos

# %%
# Función cuadrática.
def f(x):
  return x + 3**(-x)
def g(x):
  return x
def h(x):
  return - 3**(-x)

# %%
f(-5)
# Out:
# -248

# %%
# Valores del eje X que toma el gráfico.
x=np.linspace(-10, 10,100)

# %%
# Graficar ambas funciones.
#plt.plot(x, f(x))
plt.figure(figsize=(10,10))
plt.title('Gráfica x-3**-x')
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.plot(x, g(x), color="purple")
plt.plot(x, h(x), color="orange")
plt.legend({'g(x) = (x)', 'h(x)=3**-x'})
plt.axhline(1, color="red")
plt.axvline(0, color="green")
plt.xlim(-10, 10)
plt.ylim(-10, 10)
#plt.savefig("output.png") # Guardar gráfico como imágen PNG.
plt.grid(color="pink")
# Mostrarlo.
plt.show()

# %% [markdown]
# Ejercicio 1: Graficar las funciones $x$ y $3^{-x}$ en una sola figura y comentar cómo su resta da origen a la gráfica de $f(x)$.
#
# Ejercicio 2: Agregar título, color, retícula, rótulos a los ejes y aumentar el tamaño de la gráfica.
